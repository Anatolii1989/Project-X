# %%
import streamlit as st
import pandas as pd
import plotly_express as px
import plotly.graph_objects as go

df = pd.read_csv('vehicles_us.csv')

# add new column "Manufacturer"
df['manufacturer'] = df['model'].apply(lambda x: x.split()[0])

df['manufacturer'].unique()
# Out:
# array(['bmw', 'ford', 'hyundai', 'chrysler', 'toyota', 'honda', 'kia',
#        'chevrolet', 'ram', 'gmc', 'jeep', 'nissan', 'subaru', 'dodge',
#        'mercedes-benz', 'acura', 'cadillac', 'volkswagen', 'buick'],
#       dtype=object)

# %%
df.describe()
# Out:
#                price    model_year     cylinders       odometer   is_4wd  \
# count   51525.000000  47906.000000  46265.000000   43633.000000  25572.0
# mean    12132.464920   2009.750470      6.125235  115553.461738      1.0
# std     10040.803015      6.282065      1.660360   65094.611341      0.0
# min         1.000000   1908.000000      3.000000       0.000000      1.0
# 25%      5000.000000   2006.000000      4.000000   70000.000000      1.0
# 50%      9000.000000   2011.000000      6.000000  113000.000000      1.0
# 75%     16839.000000   2014.000000      8.000000  155000.000000      1.0
# max    375000.000000   2019.000000     12.000000  990000.000000      1.0
#
#        days_listed
# count  51525.00000
# mean      39.55476
# std       28.20427
# min        0.00000
# 25%       19.00000
# 50%       33.00000
# 75%       53.00000
# max      271.00000

# %%
df.shape
# Out:
# (51525, 14)

# %%
df.head(20)
# Out:
#     price  model_year                     model  condition  cylinders fuel  \
# 0    9400      2011.0                    bmw x5       good        6.0  gas
# 1   25500         NaN                ford f-150       good        6.0  gas
# 2    5500      2013.0            hyundai sonata   like new        4.0  gas
# 3    1500      2003.0                ford f-150       fair        8.0  gas
# 4   14900      2017.0              chrysler 200  excellent        4.0  gas
# 5   14990      2014.0              chrysler 300  excellent        6.0  gas
# 6   12990      2015.0              toyota camry  excellent        4.0  gas
# 7   15990      2013.0               honda pilot  excellent        6.0  gas
# 8   11500      2012.0               kia sorento  excellent        4.0  gas
# 9    9200      2008.0               honda pilot  excellent        NaN  gas
# 10  19500      2011.0  chevrolet silverado 1500  excellent        8.0  gas
# 11   8990      2012.0              honda accord  excellent        4.0  gas
# 12  18990      2012.0                  ram 1500  excellent        8.0  gas
# 13  16500      2018.0            hyundai sonata  excellent        4.0  gas
# 14  12990      2009.0                 gmc yukon  excellent        8.0  gas
# 15  17990      2013.0                  ram 1500  excellent        8.0  gas
# 16  14990      2010.0                  ram 1500  excellent        8.0  gas
# 17  13990      2014.0             jeep cherokee  excellent        6.0  gas
# 18  12500      2013.0        chevrolet traverse  excellent        6.0  gas
# 19  13990      2018.0           hyundai elantra  excellent        4.0  gas
#
#     odometer transmission    type paint_color  is_4wd date_posted  \
# 0   145000.0    automatic     SUV         NaN     1.0   6/23/2018
# 1    88705.0    automatic  pickup       white     1.0  10/19/2018
# 2   110000.0    automatic   sedan         red     NaN    2/7/2019
# 3        NaN    automatic  pickup         NaN     NaN   3/22/2019
# 4    80903.0    automatic   sedan       black     NaN    4/2/2019
# 5    57954.0    automatic   sedan       black     1.0   6/20/2018
# 6    79212.0    automatic   sedan       white     NaN  12/27/2018
# 7   109473.0    automatic     SUV       black     1.0    1/7/2019
# 8   104174.0    automatic     SUV         NaN     1.0   7/16/2018
# 9   147191.0    automatic     SUV        blue     1.0   2/15/2019
# 10  128413.0    automatic  pickup       black     1.0   9/17/2018
# 11  111142.0    automatic   sedan        grey     NaN   3/28/2019
# 12  140742.0    automatic  pickup         NaN     1.0    4/2/2019
# 13   22104.0    automatic   sedan      silver     NaN   1/14/2019
# 14  132285.0    automatic     SUV       black     1.0   1/31/2019
# 15       NaN    automatic  pickup         red     1.0   5/15/2018
# 16  130725.0    automatic  pickup         red     1.0  12/30/2018
# 17  100669.0    automatic     SUV         red     1.0   8/16/2018
# 18  128325.0    automatic     SUV       white     1.0    4/9/2019
# 19   31932.0    automatic   sedan         red     NaN   8/25/2018
#
#     days_listed manufacturer
# 0            19          bmw
# 1            50         ford
# 2            79      hyundai
# 3             9         ford
# 4            28     chrysler
# 5            15     chrysler
# 6            73       toyota
# 7            68        honda
# 8            19          kia
# 9            17        honda
# 10           38    chevrolet
# 11           29        honda
# 12           37          ram
# 13           29      hyundai
# 14           24          gmc
# 15          111          ram
# 16           13          ram
# 17           25         jeep
# 18           13    chevrolet
# 19           27      hyundai

# %%
df.isnull().sum()
# Out:
# price               0
# model_year       3619
# model               0
# condition           0
# cylinders        5260
# fuel                0
# odometer         7892
# transmission        0
# type                0
# paint_color      9267
# is_4wd          25953
# date_posted         0
# days_listed         0
# manufacturer        0
# dtype: int64
